# %%
marks = [78, 85, 92, 66, 88]

print("Marks:", marks)

total = sum(marks)
print("Total Marks:", total)

average = total / len(marks)
print("Average Marks:", average)
# Out:
# Marks: [78, 85, 92, 66, 88]
# Total Marks: 409
# Average Marks: 81.8

# %%
fruits = ["Apple", "Banana", "Mango"]
print(fruits)
fruits.append("Orange")
print(fruits)
fruits.remove("Banana")
print(fruits)
print("Updated Fruits List:", fruits)
# Out:
# ['Apple', 'Banana', 'Mango']
# ['Apple', 'Banana', 'Mango', 'Orange']
# ['Apple', 'Mango', 'Orange']
# Updated Fruits List: ['Apple', 'Mango', 'Orange']

# %%
student = {
    "name": "Hassan",
    "age": 18,
    "class": "14th",
    "marks": 540
}

print("Student Information")
print("Name:", student["name"])
print("Age:", student["age"])
print("Class:", student["class"])
print("Marks:", student["marks"])
# Out:
# Student Information
# Name: Hassan
# Age: 18
# Class: 14th
# Marks: 540

# %%
students = {
    "Ali": [80, 75, 90, 85, 70],
    "Sara": [88, 92, 79, 85, 90]
}

for name, marks in students.items():
    total = sum(marks)
    percentage = total / (len(marks) * 100) * 100
    print(name, "Percentage:", percentage, "%")
# Out:
# Ali Percentage: 80.0 %
# Sara Percentage: 86.8 %

# %%
scores = {
    "Ali": 85,
    "Sara": 90,
    "Ahmed": 78
}

# Display keys
print("Keys:", scores.keys())

# Display values
print("Values:", scores.values())

# Display key-value pairs
print("Items:", scores.items())

# Update a student's score
scores.update({"Ali": 88})

# Remove one student
scores.pop("Ahmed")

print("Updated Dictionary:", scores)
# Out:
# Keys: dict_keys(['Ali', 'Sara', 'Ahmed'])
# Values: dict_values([85, 90, 78])
# Items: dict_items([('Ali', 85), ('Sara', 90), ('Ahmed', 78)])
# Updated Dictionary: {'Ali': 88, 'Sara': 90}
